# %% [markdown]
# # Comparative Analysis between the List of "Best Books Ever" and the New York Times' 100 Notable Books of 2023

# %% [raw]
# This corpus covers book information extracted from the Goodreads website, primarily covering book titles, authors, average ratings, and the first five genre labels. The data is derived from two primary sources, the list of "Best Books Ever" and the New York Times' 100 Notable Books of 2023 on the Goodreads platform. By examining trends, author influence, genre preferences, and cross-genre patterns, the goal is to provide researchers and readers with a comprehensive resource for understanding emerging themes, influential authors, and the evolving preferences within the literary domain.

# %% [markdown]
# ## the List of "Best Books Ever

# %%
import requests
from bs4 import BeautifulSoup
import spacy

# Load spaCy English model
nlp = spacy.load("en_core_web_sm")

# Get HTML content of the book list page
url = "https://www.goodreads.com/list/show/1.Best_Books_Ever"
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the parent elements containing book information
    book_items = soup.find_all('tr', itemtype='http://schema.org/Book')[:20]

    # Iterate through each book item
    for index, book in enumerate(book_items, start=1):
        # Extract title information
        title_elem = book.find('a', class_='bookTitle')
        title = title_elem.text.strip() if title_elem else "Title not found"

        # Extract author information
        author_elem = book.find('div', class_='authorName__container')
        author = author_elem.text.strip() if author_elem else "Author not found"

        # Extract rating information
        rating_elem = book.find('span', class_='minirating')
        rating = rating_elem.text.strip() if rating_elem else "Avg Rating not found"

        # Get the URL of the book's details page
        book_url = "https://www.goodreads.com" + title_elem['href']
        
        # Get the HTML content of the book's details page
        response_book = requests.get(book_url)
        if response_book.status_code == 200:
            soup_book = BeautifulSoup(response_book.content, 'html.parser')

            # Find the parent element containing Genres information
            genres_parent_elem = soup_book.find('span', class_='BookPageMetadataSection__genrePlainText')

            # Extract Genres information
            genres = [genre_elem.text.strip() for genre_elem in genres_parent_elem.find_all('a', class_='Button__labelItem')] if genres_parent_elem else ["Genre not found"]

            # If Genres is empty, try using other information from the page
            if not genres or genres == ["Genre not found"]:
                # Find other Genres information on the page
                genres_alternative = [genre_elem.text.strip() for genre_elem in soup_book.find_all('a', class_='Button--tag-inline')]
                genres = genres_alternative[:5] if genres_alternative else ["Genre not found"]

            # Use spaCy for tokenization, lemmatization, and part-of-speech tagging
            doc = nlp(title)
            tokens = [token.text for token in doc]
            lemmas = [token.lemma_ for token in doc]
            parts_of_speech = [token.pos_ for token in doc]

            # Print book information with spaCy analysis
            print(f"{index}. {title}\nAuthor: {author}\nAvg Rating: {rating}\nGenres: {genres}")
            print("Tokens:", tokens)
            print("Lemmas:", lemmas)
            print("Parts of Speech:", parts_of_speech)
            print("---")
        else:
            print(f"Failed to retrieve information for {book_url}. Status code: {response_book.status_code}")
else:
    print(f"Failed to retrieve information for {url}. Status code: {response.status_code}")
# Out:
# 1. The Hunger Games (The Hunger Games, #1)
# Author: Suzanne Collins
# Avg Rating: 4.33 avg rating — 8,322,425 ratings
# Genres: ['Young Adult', 'Fiction', 'Fantasy', 'Dystopia', 'Science Fiction']
# Tokens: ['The', 'Hunger', 'Games', '(', 'The', 'Hunger', 'Games', ',', '#', '1', ')']
# Lemmas: ['the', 'Hunger', 'Games', '(', 'the', 'Hunger', 'Games', ',', '#', '1', ')']
# Parts of Speech: ['DET', 'PROPN', 'PROPN', 'PUNCT', 'DET', 'PROPN', 'PROPN', 'PUNCT', 'SYM', 'NUM', 'PUNCT']
# ---
# 2. Harry Potter and the Order of the Phoenix (Harry Potter, #5)
# Author: J.K. Rowling
# Avg Rating: 4.50 avg rating — 3,280,769 ratings
# Genres: ['Young Adult', 'Fiction', 'Magic', 'Childrens', 'Audiobook']
# Tokens: ['Harry', 'Potter', 'and', 'the', 'Order', 'of', 'the', 'Phoenix', '(', 'Harry', 'Potter', ',', '#', '5', ')']
# Lemmas: ['Harry', 'Potter', 'and', 'the', 'order', 'of', 'the', 'Phoenix', '(', 'Harry', 'Potter', ',', '#', '5', ')']
# Parts of Speech: ['PROPN', 'PROPN', 'CCONJ', 'DET', 'NOUN', 'ADP', 'DET', 'PROPN', 'PUNCT', 'PROPN', 'PROPN', 'PUNCT', 'SYM', 'NUM', 'PUNCT']
# ---
# 3. Pride and Prejudice
# Author: Jane Austen
# Avg Rating: 4.28 avg rating — 4,122,639 ratings
# Genres: ['Classics', 'Fiction', 'Romance', 'Historical Fiction', 'Literature']
# Tokens: ['Pride', 'and', 'Prejudice']
# Lemmas: ['Pride', 'and', 'Prejudice']
# Parts of Speech: ['PROPN', 'CCONJ', 'PROPN']
# ---
# 4. To Kill a Mockingbird
# Author: Harper Lee
# Avg Rating: 4.26 avg rating — 5,913,782 ratings
# Genres: ['Classics', 'Fiction', 'Historical Fiction', 'School', 'Literature']
# Tokens: ['To', 'Kill', 'a', 'Mockingbird']
# Lemmas: ['to', 'kill', 'a', 'Mockingbird']
# Parts of Speech: ['PART', 'VERB', 'DET', 'PROPN']
# ---
# 5. The Book Thief
# Author: Markus Zusak (Goodreads Author)
# Avg Rating: 4.39 avg rating — 2,470,068 ratings
# Genres: ['Historical Fiction', 'Fiction', 'Young Adult', 'Historical', 'Classics']
# Tokens: ['The', 'Book', 'Thief']
# Lemmas: ['the', 'Book', 'Thief']
# Parts of Speech: ['DET', 'PROPN', 'PROPN']
# ---
# 6. Twilight (The Twilight Saga, #1)
# Author: Stephenie Meyer
# Avg Rating: 3.65 avg rating — 6,367,818 ratings
# Genres: ['Young Adult', 'Romance', 'Fiction', 'Vampires', 'Paranormal']
# Tokens: ['Twilight', '(', 'The', 'Twilight', 'Saga', ',', '#', '1', ')']
# Lemmas: ['twilight', '(', 'the', 'Twilight', 'Saga', ',', '#', '1', ')']
# Parts of Speech: ['NOUN', 'PUNCT', 'DET', 'PROPN', 'PROPN', 'PUNCT', 'SYM', 'NUM', 'PUNCT']
# ---
# 7. Animal Farm
# Author: George Orwell
# Avg Rating: 3.98 avg rating — 3,745,136 ratings
# Genres: ['Classics', 'Fiction', 'Dystopia', 'Fantasy', 'School']
# Tokens: ['Animal', 'Farm']
# Lemmas: ['Animal', 'Farm']
# Parts of Speech: ['PROPN', 'PROPN']
# ---
# 8. J.R.R. Tolkien 4-Book Boxed Set: The Hobbit and The Lord of the Rings
# Author: J.R.R. Tolkien
# Avg Rating: 4.61 avg rating — 131,136 ratings
# Genres: ['Fantasy', 'Fiction', 'Classics', 'Adventure', 'Science Fiction Fantasy']
# Tokens: ['J.R.R.', 'Tolkien', '4', '-', 'Book', 'Boxed', 'Set', ':', 'The', 'Hobbit', 'and', 'The', 'Lord', 'of', 'the', 'Rings']
# Lemmas: ['J.R.R.', 'Tolkien', '4', '-', 'book', 'Boxed', 'Set', ':', 'the', 'Hobbit', 'and', 'the', 'Lord', 'of', 'the', 'Rings']
# Parts of Speech: ['PROPN', 'PROPN', 'NUM', 'PUNCT', 'NOUN', 'PROPN', 'PROPN', 'PUNCT', 'DET', 'PROPN', 'CCONJ', 'DET', 'PROPN', 'ADP', 'DET', 'PROPN']
# ---
# 9. The Chronicles of Narnia (The Chronicles of Narnia, #1-7)
# Author: C.S. Lewis
# Avg Rating: 4.27 avg rating — 636,995 ratings
# Genres: ['Fantasy', 'Classics', 'Fiction', 'Young Adult', 'Childrens']
# Tokens: ['The', 'Chronicles', 'of', 'Narnia', '(', 'The', 'Chronicles', 'of', 'Narnia', ',', '#', '1', '-', '7', ')']
# Lemmas: ['the', 'Chronicles', 'of', 'Narnia', '(', 'the', 'Chronicles', 'of', 'Narnia', ',', '#', '1', '-', '7', ')']
# Parts of Speech: ['DET', 'PROPN', 'ADP', 'PROPN', 'PUNCT', 'DET', 'PROPN', 'ADP', 'PROPN', 'PUNCT', 'SYM', 'NUM', 'SYM', 'NUM', 'PUNCT']
# ---
# 10. The Fault in Our Stars
# Author: John Green (Goodreads Author)
# Avg Rating: 4.14 avg rating — 4,959,382 ratings
# Genres: ['Young Adult', 'Fiction', 'Contemporary', 'Realistic Fiction', 'Teen']
# Tokens: ['The', 'Fault', 'in', 'Our', 'Stars']
# Lemmas: ['the', 'Fault', 'in', 'our', 'star']
# Parts of Speech: ['DET', 'PROPN', 'ADP', 'PRON', 'NOUN']
# ---
# 11. The Picture of Dorian Gray
# Author: Oscar Wilde
# Avg Rating: 4.12 avg rating — 1,466,500 ratings
# Genres: ['Classics', 'Fiction', 'Horror', 'Fantasy', 'Gothic']
# Tokens: ['The', 'Picture', 'of', 'Dorian', 'Gray']
# Lemmas: ['the', 'Picture', 'of', 'Dorian', 'Gray']
# Parts of Speech: ['DET', 'PROPN', 'ADP', 'PROPN', 'PROPN']
# ---
# 12. Gone with the Wind
# Author: Margaret Mitchell
# Avg Rating: 4.31 avg rating — 1,195,970 ratings
# Genres: ['Classics', 'Historical Fiction', 'Fiction', 'Romance', 'Historical']
# Tokens: ['Gone', 'with', 'the', 'Wind']
# Lemmas: ['go', 'with', 'the', 'wind']
# Parts of Speech: ['VERB', 'ADP', 'DET', 'NOUN']
# ---
# 13. The Giving Tree
# Author: Shel Silverstein
# Avg Rating: 4.38 avg rating — 1,095,883 ratings
# Genres: ['Childrens', 'Classics', 'Fiction', 'Picture Books', 'Poetry']
# Tokens: ['The', 'Giving', 'Tree']
# Lemmas: ['the', 'Giving', 'Tree']
# Parts of Speech: ['DET', 'PROPN', 'PROPN']
# ---
# 14. Wuthering Heights
# Author: Emily Brontë
# Avg Rating: 3.89 avg rating — 1,750,991 ratings
# Genres: ['Classics', 'Fiction', 'Romance', 'Gothic', 'Historical Fiction']
# Tokens: ['Wuthering', 'Heights']
# Lemmas: ['wuthere', 'height']
# Parts of Speech: ['VERB', 'NOUN']
# ---
# 15. The Perks of Being a Wallflower
# Author: Stephen Chbosky
# Avg Rating: 4.23 avg rating — 1,737,155 ratings
# Genres: ['Young Adult', 'Fiction', 'Coming Of Age', 'Classics', 'Romance']
# Tokens: ['The', 'Perks', 'of', 'Being', 'a', 'Wallflower']
# Lemmas: ['the', 'Perks', 'of', 'be', 'a', 'wallflower']
# Parts of Speech: ['DET', 'PROPN', 'ADP', 'AUX', 'DET', 'NOUN']
# ---
# 16. Jane Eyre
# Author: Charlotte Brontë
# Avg Rating: 4.15 avg rating — 2,045,460 ratings
# Genres: ['Classics', 'Fiction', 'Historical Fiction', 'Gothic', 'Literature']
# Tokens: ['Jane', 'Eyre']
# Lemmas: ['Jane', 'Eyre']
# Parts of Speech: ['PROPN', 'PROPN']
# ---
# 17. Harry Potter and the Sorcerer's Stone (Harry Potter, #1)
# Author: J.K. Rowling
# Avg Rating: 4.47 avg rating — 9,681,489 ratings
# Genres: ['Fiction', 'Young Adult', 'Magic', 'Childrens', 'Middle Grade']
# Tokens: ['Harry', 'Potter', 'and', 'the', 'Sorcerer', "'s", 'Stone', '(', 'Harry', 'Potter', ',', '#', '1', ')']
# Lemmas: ['Harry', 'Potter', 'and', 'the', 'Sorcerer', "'s", 'Stone', '(', 'Harry', 'Potter', ',', '#', '1', ')']
# Parts of Speech: ['PROPN', 'PROPN', 'CCONJ', 'DET', 'PROPN', 'PART', 'PROPN', 'PUNCT', 'PROPN', 'PROPN', 'PUNCT', 'SYM', 'NUM', 'PUNCT']
# ---
# 18. The Great Gatsby
# Author: F. Scott Fitzgerald
# Avg Rating: 3.93 avg rating — 5,045,064 ratings
# Genres: ['Classics', 'Fiction', 'School', 'Historical Fiction', 'Romance']
# Tokens: ['The', 'Great', 'Gatsby']
# Lemmas: ['the', 'Great', 'Gatsby']
# Parts of Speech: ['DET', 'PROPN', 'PROPN']
# ---
# 19. The Lightning Thief (Percy Jackson and the Olympians, #1)
# Author: Rick Riordan (Goodreads Author)
# Avg Rating: 4.30 avg rating — 2,840,839 ratings
# Genres: ['Fantasy', 'Young Adult', 'Mythology', 'Fiction', 'Middle Grade']
# Tokens: ['The', 'Lightning', 'Thief', '(', 'Percy', 'Jackson', 'and', 'the', 'Olympians', ',', '#', '1', ')']
# Lemmas: ['the', 'Lightning', 'Thief', '(', 'Percy', 'Jackson', 'and', 'the', 'Olympians', ',', '#', '1', ')']
# Parts of Speech: ['DET', 'PROPN', 'PROPN', 'PUNCT', 'PROPN', 'PROPN', 'CCONJ', 'DET', 'PROPN', 'PUNCT', 'SYM', 'NUM', 'PUNCT']
# ---
# 20. The Little Prince
# Author: Antoine de Saint-Exupéry
# Avg Rating: 4.32 avg rating — 2,027,597 ratings
# Genres: ['Classics', 'Fiction', 'Fantasy', 'Childrens', 'France']
# Tokens: ['The', 'Little', 'Prince']
# Lemmas: ['the', 'Little', 'Prince']
# Parts of Speech: ['DET', 'PROPN', 'PROPN']
# ---

# %% [markdown]
# ## the New York Times' 100 Notable Books of 2023

# %%
import requests
from bs4 import BeautifulSoup
import spacy

# Load the spaCy English model
nlp = spacy.load("en_core_web_sm")

# Function to process the text with spaCy
def process_text(text):
    doc = nlp(text)
    tokens = [token.text for token in doc]
    lemmas = [token.lemma_ for token in doc]
    pos_tags = [token.pos_ for token in doc]
    return tokens, lemmas, pos_tags

# Get HTML content of the book list page
url = "https://www.goodreads.com/list/show/194660.New_York_Times_100_Notable_Books_of_2023"
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the parent elements containing book information
    book_items = soup.find_all('tr', itemtype='http://schema.org/Book')[:20]

    # Iterate through each book item
    for index, book in enumerate(book_items, start=1):
        # Extract title information
        title_elem = book.find('a', class_='bookTitle')
        title = title_elem.text.strip() if title_elem else "Title not found"

        # Extract author information
        author_elem = book.find('div', class_='authorName__container')
        author = author_elem.text.strip() if author_elem else "Author not found"

        # Extract rating information
        rating_elem = book.find('span', class_='minirating')
        rating = rating_elem.text.strip() if rating_elem else "Avg Rating not found"

        # Get the URL of the book's details page
        book_url = "https://www.goodreads.com" + title_elem['href']

        # Get the HTML content of the book's details page
        response_book = requests.get(book_url)
        if response_book.status_code == 200:
            soup_book = BeautifulSoup(response_book.content, 'html.parser')

            # Find the parent element containing Genres information
            genres_parent_elem = soup_book.find('span', class_='BookPageMetadataSection__genrePlainText')

            # Extract Genres information
            genres = [genre_elem.text.strip() for genre_elem in genres_parent_elem.find_all('a', class_='Button__labelItem')] if genres_parent_elem else ["Genre not found"]

            # If Genres is empty, try using other information from the page
            if not genres or genres == ["Genre not found"]:
                # Find other Genres information on the page
                genres_alternative = [genre_elem.text.strip() for genre_elem in soup_book.find_all('a', class_='Button--tag-inline')]
                genres = genres_alternative[:5] if genres_alternative else ["Genre not found"]

            # Process text with spaCy
            tokens, lemmas, pos_tags = process_text(title)
            
            # Print book information
            print(f"{index}. {title}\nAuthor: {author}\nAvg Rating: {rating}\nGenres: {genres}")
            print(f"Tokens: {tokens}\nLemmas: {lemmas}\nParts of Speech: {pos_tags}")
            print("---")
        else:
            print(f"Failed to retrieve information for {book_url}. Status code: {response_book.status_code}")
else:
    print(f"Failed to retrieve information for {url}. Status code: {response.status_code}")
# Out:
# 1. Yellowface
# Author: R.F. Kuang (Goodreads Author)
# Avg Rating: 3.87 avg rating — 241,978 ratings
# Genres: ['Fiction', 'Contemporary', 'Audiobook', 'Literary Fiction', 'Thriller']
# Tokens: ['Yellowface']
# Lemmas: ['yellowface']
# Parts of Speech: ['NOUN']
# ---
# 2. Cobalt Red: How the Blood of the Congo Powers Our Lives
# Author: Siddharth Kara
# Avg Rating: 4.38 avg rating — 3,920 ratings
# Genres: ['Nonfiction', 'History', 'Africa', 'Politics', 'Economics']
# Tokens: ['Cobalt', 'Red', ':', 'How', 'the', 'Blood', 'of', 'the', 'Congo', 'Powers', 'Our', 'Lives']
# Lemmas: ['Cobalt', 'Red', ':', 'how', 'the', 'blood', 'of', 'the', 'Congo', 'Powers', 'our', 'life']
# Parts of Speech: ['PROPN', 'PROPN', 'PUNCT', 'SCONJ', 'DET', 'NOUN', 'ADP', 'DET', 'PROPN', 'PROPN', 'PRON', 'NOUN']
# ---
# 3. King: A Life
# Author: Jonathan Eig (Goodreads Author)
# Avg Rating: 4.68 avg rating — 2,990 ratings
# Genres: ['Biography', 'Nonfiction', 'History', 'Politics', 'Race']
# Tokens: ['King', ':', 'A', 'Life']
# Lemmas: ['king', ':', 'a', 'life']
# Parts of Speech: ['NOUN', 'PUNCT', 'DET', 'NOUN']
# ---
# 4. The Covenant of Water
# Author: Abraham   Verghese (Goodreads Author)
# Avg Rating: 4.50 avg rating — 94,478 ratings
# Genres: ['Historical Fiction', 'Fiction', 'India', 'Audiobook', 'Literary Fiction']
# Tokens: ['The', 'Covenant', 'of', 'Water']
# Lemmas: ['the', 'Covenant', 'of', 'Water']
# Parts of Speech: ['DET', 'PROPN', 'ADP', 'PROPN']
# ---
# 5. Kantika
# Author: Elizabeth Graver (Goodreads Author)
# Avg Rating: 4.12 avg rating — 1,496 ratings
# Genres: ['Historical Fiction', 'Fiction', 'Jewish', 'Historical', 'Judaism']
# Tokens: ['Kantika']
# Lemmas: ['Kantika']
# Parts of Speech: ['NOUN']
# ---
# 6. Tom Lake
# Author: Ann Patchett
# Avg Rating: 4.14 avg rating — 121,710 ratings
# Genres: ['Fiction', 'Audiobook', 'Literary Fiction', 'Historical Fiction', 'Romance']
# Tokens: ['Tom', 'Lake']
# Lemmas: ['Tom', 'Lake']
# Parts of Speech: ['PROPN', 'PROPN']
# ---
# 7. Ordinary Notes
# Author: Christina Sharpe (Goodreads Author)
# Avg Rating: 4.62 avg rating — 526 ratings
# Genres: ['Nonfiction', 'Essays', 'Memoir', 'Race', 'Poetry']
# Tokens: ['Ordinary', 'Notes']
# Lemmas: ['ordinary', 'note']
# Parts of Speech: ['ADJ', 'NOUN']
# ---
# 8. All the Sinners Bleed
# Author: S.A. Cosby (Goodreads Author)
# Avg Rating: 4.29 avg rating — 30,932 ratings
# Genres: ['Mystery', 'Fiction', 'Thriller', 'Mystery Thriller', 'Crime']
# Tokens: ['All', 'the', 'Sinners', 'Bleed']
# Lemmas: ['all', 'the', 'Sinners', 'Bleed']
# Parts of Speech: ['DET', 'DET', 'PROPN', 'PROPN']
# ---
# 9. The Bee Sting
# Author: Paul Murray
# Avg Rating: 4.07 avg rating — 8,016 ratings
# Genres: ['Fiction', 'Ireland', 'Contemporary', 'Literary Fiction', 'Irish Literature']
# Tokens: ['The', 'Bee', 'Sting']
# Lemmas: ['the', 'Bee', 'Sting']
# Parts of Speech: ['DET', 'PROPN', 'PROPN']
# ---
# 10. Biography of X
# Author: Catherine Lacey (Goodreads Author)
# Avg Rating: 3.94 avg rating — 4,754 ratings
# Genres: ['Fiction', 'Literary Fiction', 'LGBT', 'Queer', 'Contemporary']
# Tokens: ['Biography', 'of', 'X']
# Lemmas: ['biography', 'of', 'x']
# Parts of Speech: ['NOUN', 'ADP', 'NOUN']
# ---
# 11. Chain-Gang All-Stars
# Author: Nana Kwame Adjei-Brenyah (Goodreads Author)
# Avg Rating: 4.14 avg rating — 18,116 ratings
# Genres: ['Fiction', 'Science Fiction', 'Dystopia', 'LGBT', 'Fantasy']
# Tokens: ['Chain', '-', 'Gang', 'All', '-', 'Stars']
# Lemmas: ['chain', '-', 'Gang', 'All', '-', 'star']
# Parts of Speech: ['NOUN', 'PUNCT', 'PROPN', 'PROPN', 'PUNCT', 'NOUN']
# ---
# 12. Birnam Wood
# Author: Eleanor Catton
# Avg Rating: 3.84 avg rating — 20,941 ratings
# Genres: ['Fiction', 'Thriller', 'Mystery', 'Contemporary', 'Literary Fiction']
# Tokens: ['Birnam', 'Wood']
# Lemmas: ['Birnam', 'Wood']
# Parts of Speech: ['PROPN', 'PROPN']
# ---
# 13. Blackouts
# Author: Justin Torres (Goodreads Author)
# Avg Rating: 3.99 avg rating — 1,541 ratings
# Genres: ['Fiction', 'Queer', 'LGBT', 'Literary Fiction', 'Contemporary']
# Tokens: ['Blackouts']
# Lemmas: ['blackout']
# Parts of Speech: ['NOUN']
# ---
# 14. The Deluge
# Author: Stephen Markley (Goodreads Author)
# Avg Rating: 4.20 avg rating — 2,543 ratings
# Genres: ['Fiction', 'Science Fiction', 'Dystopia', 'Climate Change', 'Climate Change Fiction']
# Tokens: ['The', 'Deluge']
# Lemmas: ['the', 'Deluge']
# Parts of Speech: ['DET', 'PROPN']
# ---
# 15. From From: Poems
# Author: Monica Youn
# Avg Rating: 4.26 avg rating — 126 ratings
# Genres: ['Poetry', 'Nonfiction', 'poetry', '2023-reads', 'asian-am-can-diaspora-lit']
# Tokens: ['From', 'From', ':', 'Poems']
# Lemmas: ['from', 'from', ':', 'poem']
# Parts of Speech: ['ADP', 'ADP', 'PUNCT', 'NOUN']
# ---
# 16. A Guest in the House
# Author: Emily Carroll
# Avg Rating: 4.10 avg rating — 2,178 ratings
# Genres: ['Horror', 'Graphic Novels', 'Comics', 'Fiction', 'Adult']
# Tokens: ['A', 'Guest', 'in', 'the', 'House']
# Lemmas: ['a', 'Guest', 'in', 'the', 'House']
# Parts of Speech: ['DET', 'PROPN', 'ADP', 'DET', 'PROPN']
# ---
# 17. Eastbound
# Author: Maylis de Kerangal
# Avg Rating: 3.99 avg rating — 1,568 ratings
# Genres: ['Fiction', 'Russia', 'Historical Fiction', 'France', 'Literary Fiction']
# Tokens: ['Eastbound']
# Lemmas: ['eastbound']
# Parts of Speech: ['NOUN']
# ---
# 18. The Heaven & Earth Grocery Store
# Author: James   McBride (Goodreads Author)
# Avg Rating: 4.24 avg rating — 36,532 ratings
# Genres: ['Fiction', 'Historical Fiction', 'Literary Fiction', 'Mystery', 'Audiobook']
# Tokens: ['The', 'Heaven', '&', 'Earth', 'Grocery', 'Store']
# Lemmas: ['the', 'Heaven', '&', 'Earth', 'Grocery', 'Store']
# Parts of Speech: ['DET', 'PROPN', 'CCONJ', 'PROPN', 'PROPN', 'PROPN']
# ---
# 19. Hello Beautiful
# Author: Ann Napolitano (Goodreads Author)
# Avg Rating: 4.20 avg rating — 195,460 ratings
# Genres: ['Fiction', 'Historical Fiction', 'Audiobook', 'Contemporary', 'Literary Fiction']
# Tokens: ['Hello', 'Beautiful']
# Lemmas: ['hello', 'beautiful']
# Parts of Speech: ['INTJ', 'ADJ']
# ---
# 20. The Iliad
# Author: Homer
# Avg Rating: 3.90 avg rating — 440,396 ratings
# Genres: ['Classics', 'Poetry', 'Fiction', 'Mythology', 'Literature']
# Tokens: ['The', 'Iliad']
# Lemmas: ['the', 'Iliad']
# Parts of Speech: ['DET', 'PROPN']
# ---

# %% [markdown]
# # Creat the Data Directory Containing Corpus Files in the Text Format
# a. Corpus data of the list "Best Books Ever" will be save in the Directory named data1
#
# b. Corpus data of the New York Times' 100 Notable Books of 2023 will be save in the Directory named data2

# %%
import os
import requests
from bs4 import BeautifulSoup
import spacy

# Load spaCy English model
nlp = spacy.load("en_core_web_sm")

# Function to process the text with spaCy
def process_text(text):
    doc = nlp(text)
    tokens = [token.text for token in doc]
    lemmas = [token.lemma_ for token in doc]
    pos_tags = [token.pos_ for token in doc]
    return tokens, lemmas, pos_tags

# Function to scrape book information from a Goodreads URL and save it to a text file
def scrape_and_save_book_info(url, output_directory):
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        book_items = soup.find_all('tr', itemtype='http://schema.org/Book')[:20]

        for index, book in enumerate(book_items, start=1):
            title_elem = book.find('a', class_='bookTitle')
            title = title_elem.text.strip() if title_elem else "Title not found"

            author_elem = book.find('div', class_='authorName__container')
            author = author_elem.text.strip() if author_elem else "Author not found"

            rating_elem = book.find('span', class_='minirating')
            rating = rating_elem.text.strip() if rating_elem else "Avg Rating not found"

            # Get the URL of the book's details page
            book_url = "https://www.goodreads.com" + title_elem['href']

            # Get the HTML content of the book's details page
            response_book = requests.get(book_url)
            if response_book.status_code == 200:
                soup_book = BeautifulSoup(response_book.content, 'html.parser')

                # Find the parent element containing Genres information
                genres_parent_elem = soup_book.find('span', class_='BookPageMetadataSection__genrePlainText')
                genres = [genre_elem.text.strip() for genre_elem in genres_parent_elem.find_all('a', class_='Button__labelItem')] if genres_parent_elem else ["Genre not found"]

                # If Genres is empty, try using other information from the page
                if not genres or genres == ["Genre not found"]:
                    # Find other Genres information on the page
                    genres_alternative = [genre_elem.text.strip() for genre_elem in soup_book.find_all('a', class_='Button--tag-inline')]
                    genres = genres_alternative[:5] if genres_alternative else ["Genre not found"]

                # Process text with spaCy
                tokens, lemmas, pos_tags = process_text(title)

                # Save book information into a text file
                save_book_info_to_file(
                    title, author, rating, genres,
                    tokens, lemmas, pos_tags,
                    os.path.join(output_directory, f"Book_{index}.txt")
                )
            else:
                print(f"Failed to retrieve information for {book_url}. Status code: {response_book.status_code}")
    else:
        print(f"Failed to retrieve information for {url}. Status code: {response.status_code}")

# Function to save book information into a text file
def save_book_info_to_file(title, author, rating, genres, tokens, lemmas, pos_tags, filename):
    with open(filename, mode='w', encoding='utf-8') as file:
        file.write(f"Title: {title}\n")
        file.write(f"Author: {author}\n")
        file.write(f"Avg Rating: {rating}\n")
        file.write(f"Genres: {', '.join(genres)}\n")
        file.write(f"Tokens: {tokens}\n")
        file.write(f"Lemmas: {lemmas}\n")
        file.write(f"Parts of Speech: {pos_tags}\n")
        print(f"Saved book information to {filename}")

# URLs for the two lists
url1 = "https://www.goodreads.com/list/show/1.Best_Books_Ever"
url2 = "https://www.goodreads.com/list/show/194660.New_York_Times_100_Notable_Books_of_2023"

# Create directories to store the text files
output_directory1 = "data1"
output_directory2 = "data2"
os.makedirs(output_directory1, exist_ok=True)
os.makedirs(output_directory2, exist_ok=True)

# Scrape and save book information for both URLs in separate directories
scrape_and_save_book_info(url1, output_directory1)
scrape_and_save_book_info(url2, output_directory2)
# Out:
# Saved book information to data1\Book_1.txt
# Saved book information to data1\Book_2.txt
# Saved book information to data1\Book_3.txt
# Saved book information to data1\Book_4.txt
# Saved book information to data1\Book_5.txt
# Saved book information to data1\Book_6.txt
# Saved book information to data1\Book_7.txt
# Saved book information to data1\Book_8.txt
# Saved book information to data1\Book_9.txt
# Saved book information to data1\Book_10.txt
# Saved book information to data1\Book_11.txt
# Saved book information to data1\Book_12.txt
# Saved book information to data1\Book_13.txt
# Saved book information to data1\Book_14.txt
# Saved book information to data1\Book_15.txt
# Saved book information to data1\Book_16.txt
# Saved book information to data1\Book_17.txt
# Saved book information to data1\Book_18.txt
# Saved book information to data1\Book_19.txt
# Saved book information to data1\Book_20.txt
# Saved book information to data2\Book_1.txt
# Saved book information to data2\Book_2.txt
# Saved book information to data2\Book_3.txt
# Saved book information to data2\Book_4.txt
# Saved book information to data2\Book_5.txt
# Saved book information to data2\Book_6.txt
# Saved book information to data2\Book_7.txt
# Saved book information to data2\Book_8.txt
# Saved book information to data2\Book_9.txt
# Saved book information to data2\Book_10.txt
# Saved book information to data2\Book_11.txt
# Saved book information to data2\Book_12.txt
# Saved book information to data2\Book_13.txt
# Saved book information to data2\Book_14.txt
# Saved book information to data2\Book_15.txt
# Saved book information to data2\Book_16.txt
# Saved book information to data2\Book_17.txt
# Saved book information to data2\Book_18.txt
# Saved book information to data2\Book_19.txt
# Saved book information to data2\Book_20.txt

# %% [markdown]
# ## Creat a CSV File with All Corpus Data
# The CSV file columns of Title, Author, Avg Rating, Genres, Tokens, Lemmas, Parts of Speech, Source, Rank.

# %%
import os
import requests
from bs4 import BeautifulSoup
import spacy
import csv

# Load spaCy English model
nlp = spacy.load("en_core_web_sm")

# Function to process the text with spaCy
def process_text(text):
    doc = nlp(text)
    tokens = [token.text for token in doc]
    lemmas = [token.lemma_ for token in doc]
    pos_tags = [token.pos_ for token in doc]
    return tokens, lemmas, pos_tags

# Function to scrape book information from a Goodreads URL and save it to a CSV file
def scrape_and_save_book_info(url, output_directory, source, rank_start=1):
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        book_items = soup.find_all('tr', itemtype='http://schema.org/Book')[:20]

        rows = []
        for index, book in enumerate(book_items, start=rank_start):
            title_elem = book.find('a', class_='bookTitle')
            title = title_elem.text.strip() if title_elem else "Title not found"

            author_elem = book.find('div', class_='authorName__container')
            author = author_elem.text.strip() if author_elem else "Author not found"

            rating_elem = book.find('span', class_='minirating')
            rating = rating_elem.text.strip() if rating_elem else "Avg Rating not found"

            # Get the URL of the book's details page
            book_url = "https://www.goodreads.com" + title_elem['href']

            # Get the HTML content of the book's details page
            response_book = requests.get(book_url)
            if response_book.status_code == 200:
                soup_book = BeautifulSoup(response_book.content, 'html.parser')

                # Find the parent element containing Genres information
                genres_parent_elem = soup_book.find('span', class_='BookPageMetadataSection__genrePlainText')
                genres = [genre_elem.text.strip() for genre_elem in genres_parent_elem.find_all('a', class_='Button__labelItem')] if genres_parent_elem else ["Genre not found"]

                # If Genres is empty, try using other information from the page
                if not genres or genres == ["Genre not found"]:
                    # Find other Genres information on the page
                    genres_alternative = [genre_elem.text.strip() for genre_elem in soup_book.find_all('a', class_='Button--tag-inline')]
                    genres = genres_alternative[:5] if genres_alternative else ["Genre not found"]

                # Process text with spaCy
                tokens, lemmas, pos_tags = process_text(title)

                # Create a row for the CSV
                row = {
                    "Title": title,
                    "Author": author,
                    "Avg Rating": rating,
                    "Genres": ', '.join(genres),
                    "Tokens": tokens,
                    "Lemmas": lemmas,
                    "Parts of Speech": pos_tags,
                    "Source": source,
                    "Rank": index if source != "NYT_Notable_Books" else (index - rank_start + 1)
                }
                rows.append(row)
            else:
                print(f"Failed to retrieve information for {book_url}. Status code: {response_book.status_code}")

        return rows
    else:
        print(f"Failed to retrieve information for {url}. Status code: {response.status_code}")
        return []

# URLs for the two lists
url1 = "https://www.goodreads.com/list/show/1.Best_Books_Ever"
url2 = "https://www.goodreads.com/list/show/194660.New_York_Times_100_Notable_Books_of_2023"

# Create a directory to store the combined CSV file
output_directory_combined = "combined_data"
os.makedirs(output_directory_combined, exist_ok=True)

# Scrape and save book information for both URLs
rows_url1 = scrape_and_save_book_info(url1, output_directory_combined, source="Best_Books_Ever")
rows_url2 = scrape_and_save_book_info(url2, output_directory_combined, source="NYT_Notable_Books", rank_start=1)

# Combine the rows from both sources
combined_rows = rows_url1 + rows_url2

# Write the combined rows to a CSV file
csv_file_path = os.path.join(output_directory_combined, "combined_books.csv")
with open(csv_file_path, mode='w', encoding='utf-8', newline='') as csvfile:
    fieldnames = ["Title", "Author", "Avg Rating", "Genres", "Tokens", "Lemmas", "Parts of Speech"]
    fieldnames += ["Source", "Rank"]  # Adding Source and Rank columns to the end
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    for row in combined_rows:
        writer.writerow(row)

print(f"Saved combined book information to {csv_file_path}")
# Out:
# Saved combined book information to combined_data\combined_books.csv
